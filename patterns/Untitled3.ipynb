# %%
from bpf4 import bpf

# %%
bpf.linear(0, 0, 1, 1).plot()
# Out:
# Linear[0.0:1.0]

# %%
from em import moire

# %%
reload(moire)
# Out:
# <module 'em.moire' from '/Users/rt/dev/python/em/moire.py'>

# %%
moire.superimpose_angled(0.1, linedistance=0.08, duty=0.2, orientation="l", linedistance_grid=0.081
                        )

# %%
# !ls
# Out:
# Untitled0.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# angled-1.png
# auto.png
# grid-25mm.pdf
# superposeangled-5deg-0.25-0.2duty-p.pdf
# test.csd
# test.pdf

# %%
# !open superposeangled-5deg-0.25-0.2duty-l.pdf

# %%
moire.grid(orientation='p', saveas='grid-0.25mm-p.pdf')

# %%
reload (moire)
# moire.grid(orientation='l', linedistance=0.255, saveas='pdf')
fig = moire.superimpose_angled(angle=1, duty=0.5, orientation='l', linedistance=0.4, linedistance_grid=0.4*0.985)

# %%
moire.grid(linedistance=0.4*0.985, orientation='l', saveas='pdf')
# Out:
# saved to  grid-0.394-0.5duty-l.pdf

# %%
reload(moire)
#fig = moire.angled(angle=4, linedistance=0.3, duty=0.5, orientation='l')
fig = moire.grid_curved(elevation=0.05, orientation='l', linedistance=0.3, duty=0.07, theta1=10, theta2=170)
fig2 = moire.grid_curved(elevation=0.06, orientation='l', linedistance=0.3, duty=0.07, theta1=10, theta2=170, figure=fig)
fig2.savefig("test.pdf")
# !open test.pdf

# %%
fig.savefig("test.pdf")

# %%
# !open test.pdf

# %%
reload(moire)
# Out:
# <module 'em.moire' from '/Users/rt/dev/python/em/moire.py'>
